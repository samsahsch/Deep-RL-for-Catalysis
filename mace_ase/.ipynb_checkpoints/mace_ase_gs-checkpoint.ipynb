# %%
from ase import units
from ase.md.langevin import Langevin
from ase.io import read, write
import numpy as np
import time

from mace.calculators import MACECalculator
from mace.modules import MACE
from mace.tools.utils import get_model_config

model_path = '/global/cfs/cdirs/m5047/train_sam/mace_gs/checkpoints/MACE_model_run-123_epoch-264.pt'
device = 'cuda'

state_dict = torch.load(model_path, map_location=device)
config = get_model_config(state_dict)

model = MACE(
    r_max=config.r_max,
    num_interactions=config.num_interactions,
    num_species=config.num_species,
    hidden_irreps=config.hidden_irreps,
    MLP_irreps=config.MLP_irreps,
    atomic_energies=config.atomic_energies,
    gate=config.gate,
    avg_num_neighbors=config.avg_num_neighbors,
)

model.load_state_dict(state_dict)
calculator = MACECalculator(models=[model], device=device)

# calculator = MACECalculator(model_path='/global/cfs/cdirs/m5047/train_sam/mace_gs/checkpoints/MACE_model_run-123_epoch-264.pt', device='cuda')

init_conf = read('./initial.xyz', '0')
init_conf.set_calculator(calculator)

dyn = Langevin(init_conf, 0.5*units.fs, temperature_K=310, friction=5e-3)
def write_frame():
        dyn.atoms.write('mace_ace_gs.xyz', append=True)
dyn.attach(write_frame, interval=50)
dyn.run(100)
print("MD finished!")
# Out:
# /global/homes/s/samss/.conda/envs/mace_env/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# WARNING:root:'model_path' argument is deprecated, please use 'model_paths' in the future.
# /global/homes/s/samss/.conda/envs/mace_env/lib/python3.10/site-packages/mace/calculators/mace.py:199: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   torch.load(f=model_path, map_location=device)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 9
#       5 import time
#       7 from mace.calculators import MACECalculator
# ----> 9 calculator = MACECalculator(model_path='/global/cfs/cdirs/m5047/train_sam/mace_gs/checkpoints/MACE_model_run-123_epoch-264.pt', device='cuda')
#      10 init_conf = read('./initial.xyz', '0')
#      11 init_conf.set_calculator(calculator)
#
# File ~/.conda/envs/mace_env/lib/python3.10/site-packages/mace/calculators/mace.py:243, in MACECalculator.__init__(self, model_paths, models, device, energy_units_to_eV, length_units_to_A, default_dtype, charges_key, info_keys, arrays_keys, model_type, compile_mode, fullgraph, enable_cueq, enable_oeq, **kwargs)
#     241 # Ensure all models are on the same device
#     242 for model in self.models:
# --> 243     model.to(device)
#     245 if has_ipex and device == "xpu":
#     246     for model in self.models:
#
# AttributeError: 'dict' object has no attribute 'to'
